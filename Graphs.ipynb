# %%
import matplotlib.pyplot as plt
Validation_accuracies = [98.81,
99.27,
98.81,
99.27,
98.41,
99.01]
Number_of_head_models = ["M1","M2","M3","M4","M5","M6"]

plt.plot(Number_of_head_models,Validation_accuracies)
plt.xlabel('Different models with varying number of hidden layers and epochs using the MobilNet CNN')
plt.ylabel('Validation Accuracy obtained')
plt.title("Models vs Validation Accuracy")
plt.show()

# %%
Validation_accuracies =  [98.41,98.81,99.27]
Number_of_epochs = [5,10,20]
plt.plot(Number_of_epochs,Validation_accuracies)
plt.xlabel('Number of Epochs of a single model using the MobilNet CNN')
plt.ylabel('Validation Accuracy obtained')
plt.title("Number of epochs vs Validation Accuracy")
plt.show()

# %%
Validation_accuracies = [98.81,
99.27,
99.01]
Number_Of_hidden_layers = [59,61,62]
plt.plot(Number_Of_hidden_layers,Validation_accuracies)
plt.xlabel('Number of hidden layers of different models using the MobileNet CNN')
plt.ylabel('Validation Accuracy obtained')
plt.title("Number of hidden layers vs Validation Accuracy")
plt.show()

# %%
# layers - 2,2,3,2,1
# epochs - 15,5,10,10,10
# accuracies -88.29,49.31,88.29,87.29,86.37

# %%
Validation_accuracies = [88.29,49.31,88.29,87.29,86.37]
Models = ["M1","M2","M3","M4","M5"]

plt.plot(Models,Validation_accuracies)
plt.xlabel('Different models with varying number of hidden layers and epochs using the Built CNN')
plt.ylabel('Validation Accuracy obtained')
plt.title("Models vs Validation Accuracy")
plt.show()

# %%
Validation_accuracies =  [49.31,88.29,88.29]
Number_of_epochs = [5,10,15]
plt.plot(Number_of_epochs,Validation_accuracies)
plt.xlabel('Number of Epochs of models using the Developed CNN')
plt.ylabel('Validation Accuracy obtained')
plt.title("Number of epochs vs Validation Accuracy")
plt.show()

# %%
Validation_accuracies = [86.37,87.29,88.29]
Number_Of_hidden_layers = [1,2,3]
plt.plot(Number_Of_hidden_layers,Validation_accuracies)
plt.xlabel('Number of hidden layers of different models using the Developed CNN')
plt.ylabel('Validation Accuracy obtained')
plt.title("Number of hidden layers vs Validation Accuracy")
plt.show()

# %%
Accuracies = [99.27, 97.29, 88.29]
Models = ["MobileNet","AlexNet","CNN"]
plt.plot(Models,Accuracies)
plt.xlabel('Different implemented models')
plt.ylabel('Highest Validation Accuracy obtained')
plt.title('Different implemented models vs Validation accuracy obtained')
plt.show()
